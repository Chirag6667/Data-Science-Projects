# %% [markdown]
# # README
#
# Apple Global Portfolio: Pricing Power & Market Risk Analysis (2022-2024)
# 🚀 Overview
# This project moves beyond standard exploratory data analysis (EDA). Using a dataset of Apple’s global sales, I conducted a Strategic Health Audit of Apple’s product portfolio.
# Instead of simply identifying top sellers, I engineered economic metrics to evaluate:
# * Brand Moat: Quantifying Apple's "Pricing Power" using natural market fluctuations.
# * Revenue Risk: Assessing if Apple is dangerously dependent on specific product categories.
# * Operational Stability: Differentiating "Cash Cows" from volatile "Wildcards" for supply chain insights.
# 🧪 The Methodology & Formulas
# 1. Price Elasticity of Demand (PED)
# We utilized the \pm 8\% market jitter in the unit_price_usd column as a natural experiment to measure customer sensitivity.
# * The Logic: If Apple raises prices by 5% and sales only drop by 1%, the product has massive "Brand Moat."
# * Formula:Elasticity = % Change in Quantity Sold / % Chnage in Price
# * Interpretation: * |E| < 1 (Inelastic): High Brand Power. Customers are loyal despite price hikes.
# * |E| > 1 (Elastic): Commodity behavior. Customers are highly price-sensitive.
# 2. Herfindahl-Hirschman Index (HHI)
# To quantify Revenue Concentration Risk, I calculated the HHI score for the global product mix.
# * The Logic: Squaring market shares punishes a company for relying too heavily on one "Hero" product (like the iPhone).
# * Formula: HHI
# i=1
# (Market Sharei)^2
# benchmi
# 2
# ​
#
# * Benchmarking:
# * HHI < 1,500: Healthy Diversification.
# * HHI > 2,500: High Concentration (Strategic Risk).
# 3. Sales Stability Index (Coefficient of Variation)
# To identify "Cash Cows," I calculated the volatility of sales relative to the mean across different regions.
# * The Logic: Predictability is profitable. Low volatility suggests a stable, mature producCV = (σ / μ) * 100t line.
# * Formula:
# * Insight: Lower CV values represent "Cash Cows" (stable revenue), while high CV values represent "Wildcards" (unpredictable/seasonal revenue).
# 💻 Tech Stack & Engineering
# * Pandas: Used for time-series sorting and groupby percentage change calculations.
# * NumPy: Applied for handling numerical cleaning and infinite value resolution (arising from zero-price-change rows).
# * Seaborn/Matplotlib: Developed a Strategic Dashboard using bubble charts to map Revenue vs. Elasticity.
# * Data Integrity: Implemented a cleanup pipeline to handle NaN values generated by the pct_change() function and the ~30% missing customer ratings.
# 📊 Strategic Insights
# * The "Pro" Moat: High-end products like the Mac Pro (M2 Ultra) exhibited the lowest price elasticity, confirming that professional users are the most price-insensitive segment.
# * Ecosystem Risk: By calculating the HHI, the analysis reveals how effectively Apple’s "Accessories" and "Wearables" categories are de-risking the company's reliance on core hardware.
# * Regional Volatility: Using the Stability Index (CV), I identified which global regions offer the most "predictable" growth versus those that are high-risk/high-reward.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Setup & Loading Datasets

# %%
df = pd.read_csv("apple_global_sales_dataset.csv")
df['sale_date'] = pd.to_datetime(df['sale_date'])
df = df.sort_values(['product_name', 'region', 'sale_date'])
print("Data Loaded")
# Out:
# Data Loaded

# %%
# Pillar 1: Price Elasticity (The Brand Moat)

# %%
# we use pct_change to see how a % change in price affects % chaange in units
df['price_pct_change'] = df.groupby(['product_name', 'region'])['unit_price_usd'].pct_change()
df['qty_pct_change'] = df.groupby(['product_name', 'region'])['units_sold'].pct_change()

# %%
# Formula: Elasticity = % change in Qty / % change in price
df['elasticity'] = df['qty_pct_change'] / df['price_pct_change']

# %%
# Clean infinites from zero-price-change rows
elasticity_results = df.replace([np.inf, -np.inf], np.nan).dropna(subset=['elasticity'])
brand_moat = elasticity_results.groupby('product_name')['elasticity'].median().abs()

# %%
# Pillar 2: Revenue Concentration (The risk HHI)

# %%
product_revenue = df.groupby('product_name')['revenue_usd'].sum()

# %%
market_share_pct = (product_revenue / product_revenue.sum()) * 100
hhi_score = (market_share_pct**2).sum()

# %%
# Pillar 3: Sales Stability (The Cash Cow Index)

# %%
# CV = (Standard Deviation Mean / Mean) * 100. Lower = More Stable
stability = df.groupby(['product_name', 'region'])['units_sold'].agg(['std', 'mean'])
stability['cv'] = (stability['std'] / stability['mean']) * 100
stability_index = stability['cv'].groupby('product_name').mean().sort_values()

# %%
# The Executive Summary

# %%
print("\n" + "="*40)
print("APPLE STRATEGIC ANALYSIS SUMMARY")
print("="*40)

print(f"\n[1] REVENUE CONCENTRATION (HHI): {hhi_score:.2f}")
if hhi_score > 2500:
    print("INSIGHT: High Risk. Relies heavily on top-tier products.")
else:
    print("INSIGHT: Diversified. Strong ecosystem balance.")

print("\n[2] BRAND POWER (Elasticity: Lower is Stronger")
print(brand_moat.sort_values().to_string())

print("\n[3] STABILITY INDEX (Top 5 Predictable Products")
print(stability_index.head(5).to_string())
# Out:
# ...
# APPLE STRATEGIC ANALYSIS SUMMARY
# ...
#
# [1] REVENUE CONCENTRATION (HHI): 682.07
# INSIGHT: Diversified. Strong ecosystem balance.
#
# [2] BRAND POWER (Elasticity: Lower is Stronger
# product_name
# AirPods (2nd Gen)               0.0
# USB-C Woven Charge Cable        0.0
# iMac 24-inch (M3)               0.0
# iPad (10th Generation)          0.0
# iPad Air (M1)                   0.0
# iPad Mini (6th Gen)             0.0
# iPad Pro 11-inch (M2)           0.0
# iPad Pro 12.9-inch (M2)         0.0
# iPhone 13                       0.0
# Magic Trackpad                  0.0
# iPhone 13 Mini                  0.0
# iPhone 13 Pro Max               0.0
# iPhone 14                       0.0
# iPhone 14 Plus                  0.0
# iPhone 14 Pro                   0.0
# iPhone 14 Pro Max               0.0
# iPhone 15                       0.0
# iPhone 15 Plus                  0.0
# iPhone 15 Pro                   0.0
# iPhone 13 Pro                   0.0
# iPhone 15 Pro Max               0.0
# ...

# %%
# Visualization

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x=brand_moat, y=product_revenue, size=product_revenue, sizes=(100,2500), alpha=0.6, edgecolor='w')
# Adding Labels
for i in range(len(brand_moat)):
    plt.text(x = brand_moat.iloc[i]+0.03, y = product_revenue.iloc[i], s = brand_moat.index[i], fontsize=9, verticalalignment='center', ha='left',
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='none', pad=1))
plt.title("Apple Portfolio: Pricing Power vs Revenue", fontsize = 18, pad=20)
plt.title("Price Elasticity (customer sensitivity)", fontsize = 12)
plt.title("Total Revenue (USD)", fontsize = 12)
plt.xlim(brand_moat.min() - 0.01, brand_moat.max() + 0.05)
plt.grid(True, alpha=0.8, linestyle=':')
plt.tight_layout()             
plt.show()
